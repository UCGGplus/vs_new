# %% [markdown]
# 原始数据（CSV）
# data/synthetic_data.py 生成/模拟（现在你用它代替真实产线采集）
# data/preprocessing.py 读取/清洗/归一化/滑窗（把时间序列变成监督学习样本）
# data/dataset.py 把 numpy 数据包装成 PyTorch Dataset/DataLoader（训练时按 batch 喂给模型）
# models/ 前向计算（CNN-BiLSTM + 双注意力）输出预测值
# losses/ 计算损失（训练目标）
# train.py 训练循环（反向传播、保存最优模型）
# eval.py 评估/可视化（加载最优模型，输出指标和曲线）
